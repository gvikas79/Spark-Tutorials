# %%
a= 5

# %%
type(a)
# Out:
# int

# %%
a = 12

# %%
a = "Python"

# %%
b = "12"

# %%
type(b)
# Out:
# str

# %%
b*10
# Out:
# '12121212121212121212'

# %%
#b-10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 b-10
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
int(b)-10
# Out:
# 2

# %%
a = 10
b =5

print(a+b) #addition
print(a-b) # substraction
print(a*b) #multiplication
print(a/b) #division
print(a//b) # floor division
print(a%b) # modulo
print(a**b) #power
# Out:
# 15
# 5
# 50
# 2.0
# 2
# 0
# 100000

# %%
#Comparison Operations

print(a>b)
print(a<b)
print(a == b)
print (a>=b)
print(a<=b)
print(a!=b)
# Out:
# True
# False
# False
# True
# False
# True

# %%
c = 4
(a>b)and (a<c)
(a>b)or (a<c)
not(a ==b)
# Out:
# True

# %%
C = 10

c+C
# Out:
# 14

# %%
print("python" + " " + "programming")
# Out:
# python programming

# %%
print(a, b)
# Out:
# 10 5

# %%
a = "Python"
b = "Programming"

print(a+b)
print(a,b)
# Out:
# PythonProgramming
# Python Programming

# %%
Sales = 10000
profit = 60

print("The sales for Jan is", Sales, "and profit is", profit, "%")
# Out:
# The sales for Jan is 10000 and profit is 60 %

# %%
print("The sales for Jan is {} and profit is {}%".format(Sales, profit))
# Out:
# The sales for Jan is 10000 and profit is 60%

# %%
print(f'The sales for Jan is {Sales} and profit is {profit}%')
# Out:
# The sales for Jan is 10000 and profit is 60%

# %%
print("Vikas's diary")
# Out:
# Vikas's diary

# %%
print('"to err is human"')
# Out:
# "to err is human"

# %%
print(""" "do or die" """)
# Out:
#  "do or die"

# %%
a = int(input("Enter a Number"))

# %%
a
# Out:
# 33

# %%
x = 3
a+x
# Out:
# 36

# %%
#Slicing in strings

a = "Python Programming"

len(a)
# Out:
# 18

# %%
a[0]
# Out:
# 'P'

# %%
a[0:6]
# Out:
# 'Python'

# %%
a[0:6:2]
# Out:
# 'Pto'

# %%
str = "Welcome to Python and SQL training session"
len(str)
# Out:
# 42

# %%
print(str[2:])
print(str[:10])
print(str[3:20])
print(str[5:15:2])
print(str[-5:-1])
print(str[20:4:-1])
print(str[::-1])
# Out:
# lcome to Python and SQL training session
# Welcome to
# come to Python an
# m oPt
# ssio
# dna nohtyP ot em
# noisses gniniart LQS dna nohtyP ot emocleW

# %%
str = input("Enter a string")

if(str[:].lower() == str[::-1].lower()):
    print(f'{str} is a Palindrome')
else:
    print("Better Luck next time")
# Out:
# Malayalam is a Palindrome

# %%
str1 = "PyTHon ProgrMmiNg"
print(str1.upper())
print(str1.lower())
print(str1.title())
print(str1.capitalize())
print(str1.casefold())
print(str1.swapcase())
# Out:
# PYTHON PROGRMMING
# python progrmming
# Python Progrmming
# Python progrmming
# python progrmming
# pYthON pROGRmMInG

# %%
x = "  Python Programming  "
y = "Welcome to training session"
z = "Python %% Programming"

print(z.replace('%', ''))
print(x.strip())
print(x.lstrip())
print(x.rstrip())
print(y.split(sep= ' '))
# Out:
# Python  Programming
# Python Programming
# Python Programming
#   Python Programming
# ['Welcome', 'to', 'training', 'session']

# %%
list = y.split(sep= ' ')
print(list)
print(' '.join(list))
# Out:
# ['Welcome', 'to', 'training', 'session']
# Welcome to training session

# %%
str3 = "Python Training"
#print(str3.startswith("Python"))
print(str3.endswith("Training"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[62], line 3
#       1 str3 = "Python Training"
#       2 #print(str3.startswith("Python"))
# ----> 3 print(str3.endswith("Training").split(" "))
#
# AttributeError: 'bool' object has no attribute 'split'
