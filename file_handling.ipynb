# %%
'''f = open('student.txt', mode='w')
f.write('Hello ')
f.write('Team ')
f.write('Welcome to Python and SQL training')
f.close()
print('Writing Success')'''

f = open('student.txt', mode='r')
data = f.read()
print(data)
f.close()
# Out:
# Hello Team Welcome to Python and SQL training

# %%
f = open('student.txt', mode='r')
data = f.readlines()
print(data)
for i in data:
	print(i, end='')
f.close()
# Out:
# ['Hello Team Welcome to Python and SQL training']
# Hello Team Welcome to Python and SQL training

# %%
f = open('student.txt', mode='r')
print(f.tell())
data1 = f.read(5)
print(data1)
print(f.tell())
data2 = f.read(3)
print(data2)
print(f.tell())
# Out:
# 0
# Hello
# 5
#  Te
# 8

# %% [markdown]
# The seek function is a built-in function in Python that is used to set the current position of the file pointer within a file. The file pointer is a marker that indicates the current position in the file, and it is used to read or write data from that point. This function is particularly useful when reading or writing large files, as it allows us to move the file pointer to a specific location within the file and read or write data from that point.
#
#
# The Python File tell() method is used to find the current position of the file cursor (or pointer) within the file.
#
# This method is mostly used in scenarios where there is a need to determine whether the file cursor is either at the beginning of the file or the ending.

# %%
f = open('student.txt', mode='r')
print(f.tell())
f.seek(7)
print(f.tell())
data1 = f.read()
print(data1)
f.seek(2)
print(f.tell())
data2 = f.read()
print(data2)
# Out:
# 0
# 7
# eam Welcome to Python and SQL training
# 2
# llo Team Welcome to Python and SQL training

# %%
f = open('student.txt', mode='r+')
print(f.tell())
data = f.read()
print(f.tell())
f.write('Youtube')
print(f.tell())
print(data)
print(f.tell())
# Out:
# 0
# 52
# 59
# Hello Team Welcome to Python and SQL trainingYoutube
# 59

# %%
f = open('student.txt', mode='w+')
print(f.tell())
f.write('Youtube')
print(f.tell())
data = f.read()
print(f.tell())
print(data)
# Out:
# 0
# 7
# 7

# %%
f = open('student.txt', mode='w+')
print(f.tell())
f.write('Youtube')
print(f.tell())
f.seek(0)
print(f.tell())
data = f.read()
print(f.tell())
print(data)
# Out:
# 0
# 7
# 0
# 7
# Youtube

# %%
with open('student.txt', mode = 'r') as f:
	data = f.read()
	print(data)
	print('File Closed:',f.closed)
print('File Closed:',f.closed)

# %%
import pickle
class Student:
	def __init__(self, name, roll, address):
		self.name = name
		self.roll = roll
		self.address = address
		
	def disp(self):
		print(f'Name: {self.name} Roll: {self.roll} Address: {self.address}')
		
with open('student.dat', mode='wb') as f:
	stu1 = Student('Rahul', 101, 'Ranchi')
	pickle.dump(stu1, f)
	print('Pickling Done!')
	
with open('student.dat', mode='rb') as f:
	obj = pickle.load(f)
	print('Unpickling Done!')
	obj.disp()
# Out:
# Pickling Done!
# Unpickling Done!
# Name: Rahul Roll: 101 Address: Ranchi

# %%
import os
print(os.getcwd())

# %%
import os
os.mkdir('mydir')
os.mkdir('mydir/mychilddir')

# %%
import os
os.makedirs('parentdir/childdir/grandchilddir')

# %%
import os
print(os.getcwd())
os.chdir('mydir')
print(os.getcwd())

# %%
import os
w = os.walk('.')
for i in w:
	print(i)
print()

w = os.walk('yourdir')
for i in w:
	print(i)
print()

w = os.walk('yourdir', topdown=False)
for i in w:
	print(i)

# %%
os.removedirs('parentdir/childdir/grandchilddir')

# %%
os.getcwd()

# %%
Hello my name is Vikas
I am a freelance trainer
I love my job
